# %%
#Data path: f"s3://churn-data-store/bronze/"
# Out:
# Welcome to the Glue Interactive Sessions Kernel
# For more information on available magic commands, please type %help in any new cell.
#
# Please view our Getting Started page to access the most up-to-date information on the Interactive Sessions kernel: https://docs.aws.amazon.com/glue/latest/dg/interactive-sessions.html
# Installed kernel version: 1.0.9

# %% [markdown]
# ## 1. Data Preparation
#
# The first major task is to access and evaluate the data.
# The dataset comes from multiple sources and contains information about user subscriptions and streaming activities.
#
# ### **Datasets**
#
# - **User Profile data – `members.csv`**
#   Includes user demographic details:
#   - Age
#   - City
#   - Registration date/time
#
# - **User Logs data – `user_logs.csv`**
#   Captures each user's streaming behavior:
#   - Songs played per day
#   - Playback activity history
#
# - **User Transaction data – `transactions.csv`**
#   Contains subscription-related information:
#   - Payment method
#   - Subscription renewal / cancellation status
#
# - **Historical / Label data – `train.csv`**
#   Includes:
#   - `user_id`
#   - `is_churn` (target variable indicating churn or not)

# %%
from awsglue.context import GlueContext
from pyspark.context import SparkContext
from pyspark.sql import SparkSession

sc = SparkContext.getOrCreate()
glueContext = GlueContext(sc)
spark = glueContext.spark_session
# Out:
# Trying to create a Glue session for the kernel.
# Session Type: etl
# Session ID: b9afeec7-189a-40a1-ad73-27674a74db3f
# Applying the following default arguments:
# --glue_kernel_version 1.0.9
# --enable-glue-datacatalog true
# Following exception encountered while creating session: An error occurred (AccessDeniedException) when calling the CreateSession operation: User: arn:aws:sts::751081874324:assumed-role/AmazonSageMaker-ExecutionRole-20251103T142910/SageMaker is not authorized to perform: glue:CreateSession on resource: arn:aws:glue:ap-south-1:751081874324:session/b9afeec7-189a-40a1-ad73-27674a74db3f because no identity-based policy allows the glue:CreateSession action
#
# Error message: User: arn:aws:sts::751081874324:assumed-role/AmazonSageMaker-ExecutionRole-20251103T142910/SageMaker is not authorized to perform: glue:CreateSession on resource: arn:aws:glue:ap-south-1:751081874324:session/b9afeec7-189a-40a1-ad73-27674a74db3f because no identity-based policy allows the glue:CreateSession action
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/site-packages/aws_glue_interactive_sessions_kernel/glue_kernel_utils/KernelGateway.py", line 104, in create_session
#     response = self.glue_client.create_session(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/botocore/client.py", line 569, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/botocore/client.py", line 1023, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.AccessDeniedException: An error occurred (AccessDeniedException) when calling the CreateSession operation: User: arn:aws:sts::751081874324:assumed-role/AmazonSageMaker-ExecutionRole-20251103T142910/SageMaker is not authorized to perform: glue:CreateSession on resource: arn:aws:glue:ap-south-1:751081874324:session/b9afeec7-189a-40a1-ad73-27674a74db3f because no identity-based policy allows the glue:CreateSession action
# Exception encountered while creating session: An error occurred (AccessDeniedException) when calling the CreateSession operation: User: arn:aws:sts::751081874324:assumed-role/AmazonSageMaker-ExecutionRole-20251103T142910/SageMaker is not authorized to perform: glue:CreateSession on resource: arn:aws:glue:ap-south-1:751081874324:session/b9afeec7-189a-40a1-ad73-27674a74db3f because no identity-based policy allows the glue:CreateSession action
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.12/site-packages/aws_glue_interactive_sessions_kernel/glue_kernel_base/BaseKernel.py", line 168, in do_execute
#     self.create_session()
#   File "/opt/conda/lib/python3.12/site-packages/aws_glue_interactive_sessions_kernel/glue_kernel_base/BaseKernel.py", line 592, in create_session
#     response = self.kernel_gateway.create_session(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/aws_glue_interactive_sessions_kernel/glue_kernel_utils/KernelGateway.py", line 104, in create_session
#     response = self.glue_client.create_session(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/botocore/client.py", line 569, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.12/site-packages/botocore/client.py", line 1023, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.errorfactory.AccessDeniedException: An error occurred (AccessDeniedException) when calling the CreateSession operation: User: arn:aws:sts::751081874324:assumed-role/AmazonSageMaker-ExecutionRole-20251103T142910/SageMaker is not authorized to perform: glue:CreateSession on resource: arn:aws:glue:ap-south-1:751081874324:session/b9afeec7-189a-40a1-ad73-27674a74db3f because no identity-based policy allows the glue:CreateSession action
